# %%
import pandas as pd
from pathlib import Path
import fuzzymatcher

hospital_accounts = pd.read_csv('./sample/hospital_account_info.csv')
hospital_reimbursement = pd.read_csv('./sample/hospital_reimbursement.csv')

# %%
left_on = ["Facility Name", "Address", "City", "State"]

right_on = [
    "Provider Name", "Provider Street Address", "Provider City",
    "Provider State"
]

# %%
matched_results = fuzzymatcher.fuzzy_left_join(hospital_accounts,
                                            hospital_reimbursement,
                                            left_on,
                                            right_on,
                                            left_id_col='Account_Num',
                                            right_id_col='Provider_Num')

# %%
cols = [
    "best_match_score", "Facility Name", "Provider Name", "Address", "Provider Street Address",
    "Provider City", "City", "Provider State", "State"
]

matched_results[cols].sort_values(by=['best_match_score'], ascending=False).head(5)
# Out:
#         best_match_score                                      Facility Name  \
# 77870           3.090931    RARITAN BAY MEDICAL CENTER PERTH AMBOY DIVISION
# 533099          2.799072            ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL
# 78480           2.785132  AVERA MCKENNAN HOSPITAL & UNIVERSITY HEALTH CE...
# 242621          2.778860  JOHN T MATHER MEMORIAL HOSPITAL  OF PORT JEFFE...
# 447953          2.721425               MAYO CLINIC HEALTH SYSTEM - RED WING
#
#                                             Provider Name  \
# 77870     RARITAN BAY MEDICAL CENTER PERTH AMBOY DIVISION
# 533099            ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL
# 78480   AVERA MCKENNAN HOSPITAL & UNIVERSITY HEALTH CE...
# 242621  JOHN T MATHER MEMORIAL HOSPITAL  OF PORT JEFFE...
# 447953              MAYO CLINIC HEALTH SYSTEM IN RED WING
#
#                                        Address  \
# 77870                    530 NEW BRUNSWICK AVE
# 533099           ONE ROBERT WOOD JOHNSON PLACE
# 78480   1325 S CLIFF AVE  POST OFFICE BOX 5045
# 242621                   75 NORTH COUNTRY ROAD
# 447953         701 HEWITT BOULEVARD, PO BOX 95
#
#                        Provider Street Address   Provider City  \
# 77870                    530 NEW BRUNSWICK AVE     PERTH AMBOY
# 533099           ONE ROBERT WOOD JOHNSON PLACE   NEW BRUNSWICK
# 78480   1325 S CLIFF AVE  POST OFFICE BOX 5045     SIOUX FALLS
# 242621                   75 NORTH COUNTRY ROAD  PORT JEFFERSON
# 447953         701 HEWITT BOULEVARD, PO BOX 95        RED WING
#
#                   City Provider State State
# 77870      PERTH AMBOY             NJ    NJ
# 533099   NEW BRUNSWICK             NJ    NJ
# 78480      SIOUX FALLS             SD    SD
# 242621  PORT JEFFERSON             NY    NY
# 447953        RED WING             MN    MN

# %%
matched_results[cols].sort_values(by=['best_match_score'], ascending=True).head(5)
# Out:
#         best_match_score                                      Facility Name  \
# 426931         -2.268231                      CENTRO MEDICO WILMA N VAZQUEZ
# 83032          -2.124071  DOCTOR CENTER HOSPITAL SAN FERNANDO DE LA CARO...
# 42594          -2.106746     HOSPITAL ONCOLOGICO DR ISAAC GONZALEZ MARTINEZ
# 450849         -2.050888           CENTRO DE SALUD CONDUCTUAL MENONITA-CIMA
# 476692         -1.996508             ADMIN DE SERVICIOS MEDICOS  PUERTO RIC
#
#                            Provider Name  \
# 426931       BAPTIST MEDICAL CENTER EAST
# 83032   OVERLAKE HOSPITAL MEDICAL CENTER
# 42594             SCRIPPS MERCY HOSPITAL
# 450849   MILFORD REGIONAL MEDICAL CENTER
# 476692              MAINE MEDICAL CENTER
#
#                                                   Address  \
# 426931      CARR. 2 KM 39.5    ROAD NUMBER 2 BO ALGARROBO
# 83032   EDIF JESUS T PINEIRO AVE FERNANDEZ JUNCOS BO P...
# 42594   BO. MONACILLOS CARR 22 CENTRO MEDICO DE PUERTO...
# 450849  CARR ESTATAL 14 INTERIOR SARGENTO GERARDO SANT...
# 476692                           BO MONACILLO CARR NUM 22
#
#        Provider Street Address Provider City       City Provider State State
# 426931         400 TAYLOR ROAD    MONTGOMERY  VEGA BAJA             AL    PR
# 83032        1035-116TH AVE NE      BELLEVUE   CAROLINA             WA    PR
# 42594             4077 5TH AVE     SAN DIEGO   SAN JUAN             CA    PR
# 450849      14 PROSPECT STREET       MILFORD   AIBONITO             MA    PR
# 476692          22 BRAMHALL ST      PORTLAND   SAN JUAN             ME    PR

# %%
matched_results[cols].query("best_match_score <= .80").sort_values(
    by=['best_match_score'], ascending=False).head(5)
# Out:
#         best_match_score                  Facility Name  \
# 518625          0.792471       METHODIST HOSPITAL SOUTH
# 417582          0.791668  ADVENTIST HEALTH UKIAH VALLEY
# 303502          0.787163                 MADISON HEALTH
# 388981          0.776632      PENN HIGHLANDS CLEARFIELD
# 493375          0.775573  MEMORIAL HOSPITAL AT GULFPORT
#
#                               Provider Name                Address  \
# 518625  SOUTH TEXAS REGIONAL MEDICAL CENTER       1905 HWY 97 EAST
# 417582          UKIAH VALLEY MEDICAL CENTER     275 HOSPITAL DRIVE
# 303502          MADISON COUNTY HOSPITAL INC  210 NORTH MAIN STREET
# 388981                  CLEARFIELD HOSPITAL       809 TURNPIKE AVE
# 493375        MEMORIAL HOSPITAL AT GULFPORT       4500 13TH STREET
#
#           Provider Street Address Provider City        City Provider State  \
# 518625           1905 HWY 97 EAST    JOURDANTON  JOURDANTON             TX
# 417582         275 HOSPITAL DRIVE         UKIAH       UKIAH             CA
# 303502      210 NORTH MAIN STREET        LONDON      LONDON             OH
# 388981           809 TURNPIKE AVE    CLEARFIELD  CLEARFIELD             PA
# 493375  4500 13TH ST-P O BOX 1810      GULFPORT    GULFPORT             MS
#
#        State
# 518625    TX
# 417582    CA
# 303502    OH
# 388981    PA
# 493375    MS
